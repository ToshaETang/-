# %%
on=False

def hit_a():
    if on:
    var_a.set('原始分數: 20')
    N = 20                                         #之後分數運算用

var_a=tk.StringVar()
var_a.set('')

label_a = tk.Label(root, textvariable=var_a)
label_a.place(x=x_i_l[0], y=y_j_l[0], width=180, height=20)

a = tk.Button(root, text='安森', bg='pink',state=tk.NORMAL, command=hit_a)
a.place(x=x_i_b[0], y=y_j_b[0], width=50, height=50)

# ###########

# def hit_b():
#     var_b.set('原始分數: 25')
#     N = 25

# var_b=tk.StringVar()
# var_b.set('')

# label_b = tk.Label(root, textvariable=var_b)
# label_b.place(x=x_i_l[0], y=y_j_l[1], width=180, height=20)

# b = tk.Button(root, text='北車', bg='pink',state=tk.NORMAL, command=hit_b)
# b.place(x=x_i_b[0], y=y_j_b[1], width=50, height=50)

# ############

# def hit_c():
#     var_c.set('原始分數: 30')
#     N = 30

# var_c=tk.StringVar()
# var_c.set('')

# label_c = tk.Label(root, textvariable=var_c)
# label_c.place(x=x_i_l[0], y=y_j_l[2], width=180, height=20)

# c = tk.Button(root, text='中山', bg='pink',state=tk.NORMAL, command=hit_c)
# c.place(x=x_i_b[0], y=y_j_b[2], width=50, height=50)

# ############

# def hit_d():
#     var_d.set('原始分數: 40')
#     N = 40

# var_d=tk.StringVar()
# var_d.set('')

# label_d = tk.Label(root, textvariable=var_d)
# label_d.place(x=x_i_l[0], y=y_j_l[3], width=180, height=20)

# d = tk.Button(root, text='圓山', bg='pink',state=tk.NORMAL, command=hit_d)
# d.place(x=x_i_b[0], y=y_j_b[3], width=50, height=50)

# ############

# def hit_e():
#     var_e.set('原始分數: 40')
#     N = 40

# var_e=tk.StringVar()
# var_e.set('')

# label_e = tk.Label(root, textvariable=var_e)
# label_e.place(x=x_i_l[0], y=y_j_l[3], width=180, height=20)

# e = tk.Button(root, text='松山', bg='pink',state=tk.NORMAL, command=hit_e)
# e.place(x=x_i_b[0], y=y_j_b[3], width=50, height=50)

# ############

# def hit_f():
#     var_f.set('原始分數: 30')
#     N = 30

# var_f=tk.StringVar()
# var_f.set('')

# label_f = tk.Label(root, textvariable=var_f)
# label_f.place(x=x_i_l[0], y=y_j_l[4], width=180, height=20)

# f = tk.Button(root, text='北門', bg='pink',state=tk.NORMAL, command=hit_f)
# f.place(x=x_i_b[0], y=y_j_b[4], width=50, height=50)

# ############

# def hit_g():
#     var_g.set('原始分數: 30')
#     N = 30

# var_g=tk.StringVar()
# var_g.set('')

# label_g = tk.Label(root, textvariable=var_g)
# label_g.place(x=x_i_l[0], y=y_j_l[5], width=180, height=20)

# g = tk.Button(root, text='北門', bg='pink',state=tk.NORMAL, command=hit_g)
# g.place(x=x_i_b[0], y=y_j_b[5], width=50, height=50)

# ############

# def hit_h():
#     var_h.set('原始分數: 20')
#     N = 20

# var_h=tk.StringVar()
# var_h.set('')

# label_h = tk.Label(root, textvariable=var_h)
# label_h.place(x=x_i_l[0], y=y_j_l[6], width=180, height=20)

# h = tk.Button(root, text='小南門', bg='pink',state=tk.NORMAL, command=hit_h)
# h.place(x=x_i_b[0], y=y_j_b[6], width=50, height=50)

# ############

# def hit_i():
#     var_i.set('原始分數: 25')
#     N = 25

# var_i=tk.StringVar()
# var_i.set('')

# label_i = tk.Label(root, textvariable=var_i)
# label_i.place(x=x_i_l[0], y=y_j_l[7], width=180, height=20)

# i = tk.Button(root, text='景美', bg='pink',state=tk.NORMAL, command=hit_i)
# i.place(x=x_i_b[0], y=y_j_b[7], width=50, height=50)

# %%
def hit_b():
    global on
    if on==False:
        var_b.set('原始分數: 25')
        N = 25
        on=True
    else:
        var_b.set('')
        on=False

var_b=tk.StringVar()
var_b.set('')

label_b = tk.Label(root, textvariable=var_b)
label_b.place(x=x_i_l[0], y=y_j_l[1], width=180, height=20)

b = tk.Button(root, text='北車', bg='pink',state=tk.NORMAL, command=hit_b)
b.place(x=x_i_b[0], y=y_j_b[1], width=50, height=50)

############

def hit_c():
    global on
    if on==False:
        var_c.set('原始分數: 30')
        N = 30
        on=True
    else:
        var_c.set('')
        on=False

var_c=tk.StringVar()
var_c.set('')

label_c = tk.Label(root, textvariable=var_c)
label_c.place(x=x_i_l[0], y=y_j_l[2], width=180, height=20)

c = tk.Button(root, text='中山', bg='pink',state=tk.NORMAL, command=hit_c)
c.place(x=x_i_b[0], y=y_j_b[2], width=50, height=50)

############

def hit_d():
    global on
    if on==False:
        var_d.set('原始分數: 40')
        N = 40
        on=True
    else:
        var_d.set('')
        on=False

var_d=tk.StringVar()
var_d.set('')

label_d = tk.Label(root, textvariable=var_d)
label_d.place(x=x_i_l[0], y=y_j_l[3], width=180, height=20)

d = tk.Button(root, text='圓山', bg='pink',state=tk.NORMAL, command=hit_d)
d.place(x=x_i_b[0], y=y_j_b[3], width=50, height=50)

############

def hit_e():
    global on
    if on==False:
        var_e.set('原始分數: 40')
        N = 40
        on=True
    else:
        var_e.set('')
        on=False

var_e=tk.StringVar()
var_e.set('')

label_e = tk.Label(root, textvariable=var_e)
label_e.place(x=x_i_l[0], y=y_j_l[3], width=180, height=20)

e = tk.Button(root, text='松山', bg='pink',state=tk.NORMAL, command=hit_e)
e.place(x=x_i_b[0], y=y_j_b[3], width=50, height=50)

############

def hit_f():
    global on
    if on==False:
        var_f.set('原始分數: 30')
        N = 30
        on=True
    else:
        var_f.set('')
        on=False

var_f=tk.StringVar()
var_f.set('')

label_f = tk.Label(root, textvariable=var_f)
label_f.place(x=x_i_l[0], y=y_j_l[4], width=180, height=20)

f = tk.Button(root, text='北門', bg='pink',state=tk.NORMAL, command=hit_f)
f.place(x=x_i_b[0], y=y_j_b[4], width=50, height=50)

############

def hit_g():
    global on
    if on==False:
        var_g.set('原始分數: 30')
        N = 30
        on=True
    else:
        var_g.set('')
        on=False

var_g=tk.StringVar()
var_g.set('')

label_g = tk.Label(root, textvariable=var_g)
label_g.place(x=x_i_l[0], y=y_j_l[5], width=180, height=20)

g = tk.Button(root, text='北門', bg='pink',state=tk.NORMAL, command=hit_g)
g.place(x=x_i_b[0], y=y_j_b[5], width=50, height=50)

############

def hit_h():
    global on
    if on==False:
        var_h.set('原始分數: 20')
        N = 20
        on=True
    else:
        var_h.set('')
        on=False

var_h=tk.StringVar()
var_h.set('')

label_h = tk.Label(root, textvariable=var_h)
label_h.place(x=x_i_l[0], y=y_j_l[6], width=180, height=20)

h = tk.Button(root, text='小南門', bg='pink',state=tk.NORMAL, command=hit_h)
h.place(x=x_i_b[0], y=y_j_b[6], width=50, height=50)

############

def hit_i():
    global on
    if on==False:
        var_i.set('原始分數: 25')
        N = 25
        on=True
    else:
        var_i.set('')
        on=False

var_i=tk.StringVar()
var_i.set('')

label_i = tk.Label(root, textvariable=var_i)
label_i.place(x=x_i_l[0], y=y_j_l[7], width=180, height=20)

i = tk.Button(root, text='景美', bg='pink',state=tk.NORMAL, command=hit_i)
i.place(x=x_i_b[0], y=y_j_b[7], width=50, height=50)
