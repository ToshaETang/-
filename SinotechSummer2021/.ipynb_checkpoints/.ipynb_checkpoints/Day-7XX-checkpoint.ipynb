# %%
import pandas as pd
import datetime
import pytz
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
#---------------------------------------去掉紅色警告-------------
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-582d0106b7b5> in <module>
# ----> 1 import pandas as pd
#       2 import datetime
#       3 import pytz
#       4 import plotly.express as px
#       5 import plotly.graph_objects as go
#
# c:\users\tosha.e.t\appdata\local\programs\python\python39\lib\site-packages\pandas\__init__.py in <module>
#     177
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     181
#
# c:\users\tosha.e.t\appdata\local\programs\python\python39\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# c:\users\tosha.e.t\appdata\local\programs\python\python39\lib\site-packages\pandas\_testing.py in <module>
#    3052
#    3053
# ...

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.9.exe and pip3.exe are installed in 'C:\Users\Tosha.E.T\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\users\tosha.e.t\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\大竹坑_10_1_20210501_20210816.xlsx')

df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)
        
df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\大竹坑_10_1_d1.csv')
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\大竹坑_10_1_d2.csv')
print("資料切割完成")

# %%
# print("紅色是distance2")

# for q in range(1,3):
#     for j in range(1,5):
#         m=q
#         n=j
#         try:
#             df = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\20210816_抓沖蝕資料\大竹坑_10_{0}_20210501_20210816.xlsx'.format(m))
#             df1 = df.drop(['distance2'],axis=1)
#             print(m,n)
#             df1.Time = pd.to_datetime(df1['Time'])
#             for i in range(len(df1)):
#                 df1['Time'][i]=df1['Time'][i].replace(tzinfo=None)
#             df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d1.csv'.format(m,n),index=False)
#             print("{0}-{1}-d1 SAVE!".format(m,n))            
#             df2 = df.drop(['distance1'],axis=1)
#             df2.Time = pd.to_datetime(df2['Time'])
            
#             for i in range(len(df2)):
#                 df2['Time'][i]=df2['Time'][i].replace(tzinfo=None)
#             df2.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d2.csv'.format(m,n),index=False)
#             print("{0}-{1}-d2 SAVE!".format(m,n))
            
#             fig = px.line(df1, y='distance1', x='Time')
#             fig.show()
#             print("                                          {0}-{1}-1".format(m,n))
                
#             fig2 = px.line(df2, y='distance2', x='Time')
#             fig2.show()
#             print("                                          {0}-{1}-2".format(m,n))
#         except:
#             pass

# %%
# print("紅色是distance2")

# for q in range(3,4):
#     for j in range(1,5):
#         m=q
#         n=j
#         try:
#             df = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}.csv'.format(m,n))
#             df1 = df.drop(['distance2'],axis=1)
#             print(m,n)
#             df1.Time = pd.to_datetime(df1['Time'])
#             for i in range(len(df1)):
#                 df1['Time'][i]=df1['Time'][i].replace(tzinfo=None)
#             df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d1.csv'.format(m,n),index=False)
#             print("{0}-{1}-d1 SAVE!".format(m,n))            
#             df2 = df.drop(['distance1'],axis=1)
#             df2.Time = pd.to_datetime(df2['Time'])
            
#             for i in range(len(df2)):
#                 df2['Time'][i]=df2['Time'][i].replace(tzinfo=None)
#             df2.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d2.csv'.format(m,n),index=False)
#             print("{0}-{1}-d2 SAVE!".format(m,n))
            
#             fig = px.line(df1, y='distance1', x='Time')
#             fig.show()
#             print("                                          {0}-{1}-1".format(m,n))
                
#             fig2 = px.line(df2, y='distance2', x='Time')
#             fig2.show()
#             print("                                          {0}-{1}-2".format(m,n))
#         except:
#             pass

# %%
# print("紅色是distance2")

# for q in range(4,5):
#     for j in range(1,5):
#         m=q
#         n=j
#         try:
#             df = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}.csv'.format(m,n))
#             df1 = df.drop(['distance2'],axis=1)
#             print(m,n)
#             df1.Time = pd.to_datetime(df1['Time'])
#             for i in range(len(df1)):
#                 df1['Time'][i]=df1['Time'][i].replace(tzinfo=None)
#             df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d1.csv'.format(m,n),index=False)
#             print("{0}-{1}-d1 SAVE!".format(m,n))            
#             df2 = df.drop(['distance1'],axis=1)
#             df2.Time = pd.to_datetime(df2['Time'])
            
#             for i in range(len(df2)):
#                 df2['Time'][i]=df2['Time'][i].replace(tzinfo=None)
#             df2.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d2.csv'.format(m,n),index=False)
#             print("{0}-{1}-d2 SAVE!".format(m,n))
            
#             fig = px.line(df1, y='distance1', x='Time')
#             fig.show()
#             print("                                          {0}-{1}-1".format(m,n))
                
#             fig2 = px.line(df2, y='distance2', x='Time')
#             fig2.show()
#             print("                                          {0}-{1}-2".format(m,n))
#         except:
#             pass

# %%
# print("紅色是distance2")

# for q in range(5,6):
#     for j in range(1,5):
#         m=q
#         n=j
#         try:
#             df = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}.csv'.format(m,n))
#             df1 = df.drop(['distance2'],axis=1)
#             df1.Time = pd.to_datetime(df1['Time'])
#             for i in range(len(df1)):
#                 df1['Time'][i]=df1['Time'][i].replace(tzinfo=None)
#             df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d1.csv'.format(m,n),index=False)
#             print("{0}-{1}-d1 SAVE!".format(m,n))            
#             df2 = df.drop(['distance1'],axis=1)
#             df2.Time = pd.to_datetime(df2['Time'])
            
#             for i in range(len(df2)):
#                 df2['Time'][i]=df2['Time'][i].replace(tzinfo=None)
#             df2.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d2.csv'.format(m,n),index=False)
#             print("{0}-{1}-d2 SAVE!".format(m,n))
            
#             fig = px.line(df1, y='distance1', x='Time')
#             fig.show()
#             print("                                          {0}-{1}-1".format(m,n))
                
#             fig2 = px.line(df2, y='distance2', x='Time')
#             fig2.show()
#             print("                                          {0}-{1}-2".format(m,n))
#         except:
#             pass

# %%
m=26

df = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\高義-21C080.csv')
df['時間']=pd.to_datetime(df['時間'])
df1=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\1-4-d1.csv')
df1.Time=pd.to_datetime(df1.Time)


t1 = go.Scatter(
    x=df1['Time'],
    y=df1['distance1'],
    name='1-4',
    xaxis='x',
    yaxis='y1',
    mode = 'lines+markers',
    line=dict(color='green',width=1)        
)



t = go.Bar(
    x=df['時間'],
    y=df['時雨量'],
    name='時雨量',
    xaxis='x',
    yaxis='y2',
    marker=dict(color='red'),
)

data=[t,t1]

layout=go.Layout({
            "xaxis":{'title':"時間"},
            "yaxis":{'title':"ditance","side":'right'},
            "yaxis2":{'anchor':'x','overlaying':'y','title':"時雨量"}}
)

fig = go.Figure(data=data,layout=layout)
fig.show()
print("{}".format(m))
# Out:
# <div>                            <div id="4aaaf7ae-0dbf-4b9d-b26b-bd685e642e87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4aaaf7ae-0dbf-4b9d-b26b-bd685e642e87")) {                    Plotly.newPlot(                        "4aaaf7ae-0dbf-4b9d-b26b-bd685e642e87",                        [{"marker":{"color":"red"},"name":"\u6642\u96e8\u91cf","type":"bar","x":["2021-05-01T09:00:00","2021-05-01T10:00:00","2021-05-01T11:00:00","2021-05-01T12:00:00","2021-05-01T13:00:00","2021-05-01T14:00:00","2021-05-01T15:00:00","2021-05-01T16:00:00","2021-05-01T17:00:00","2021-05-01T18:00:00","2021-05-01T19:00:00","2021-05-01T20:00:00","2021-05-01T21:00:00","2021-05-01T22:00:00","2021-05-01T23:00:00","2021-05-02T00:00:00","2021-05-02T01:00:00","2021-05-02T02:00:00"
# ...

# %%
for q in range(5,6):
    for j in range(1,5):
        m=q
        n=j
        try:
            df = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\高義-21C080.csv')
            df['時間']=pd.to_datetime(df['時間'])
            df1=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\1-4-d1.csv')
            df1.Time=pd.to_datetime(df1.Time)


            t1 = go.Scatter(
                x=df1['Time'],
                y=df1['distance1'],
                name='1-4',
                xaxis='x',
                yaxis='y1',
                mode = 'lines+markers',
                line=dict(color='green',width=1)        
            )



            t = go.Bar(
                x=df['時間'],
                y=df['時雨量'],
                name='時雨量',
                xaxis='x',
    yaxis='y2',
    marker=dict(color='red'),
)

data=[t,t1]

layout=go.Layout({
            "xaxis":{'title':"時間"},
            "yaxis":{'title':"ditance","side":'right'},
            "yaxis2":{'anchor':'x','overlaying':'y','title':"時雨量"}}
)

fig = go.Figure(data=data,layout=layout)
fig.show()
print("{}".format(m))
            
        except:
            pass

# %%
m=1
n=4
s=1


df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<35]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")

# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=1
n=4
s=2


df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<50]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=1
s=1


df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<40]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")

# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=1
s=2


df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1.Time = pd.to_datetime(df1.Time)
df1.set_index('Time', drop=True, inplace=True)
df1 = df1.resample('1D').mean()

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<60]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

# df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=3
s=1


df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<60]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=3
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<55]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=4
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<45]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=2
n=4
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<35]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=1
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<52]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=1
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<92]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=2
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<40]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=2
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<50]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=4
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1.Time = pd.to_datetime(df1.Time)
df2.Time = pd.to_datetime(df2.Time)

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<45]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=3
n=4
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1.Time = pd.to_datetime(df1.Time)
df2.Time = pd.to_datetime(df2.Time)

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>30]
df1=df1[df1['distance{}'.format(s)]<50]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=4
n=3
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<35]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=4
n=3
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<32]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=4
n=4
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<70]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=4
n=4
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1['Time']=pd.to_datetime(df1['Time'])
df2['Time']=pd.to_datetime(df2['Time'])

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<70]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df2, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df1['distance{}'.format(s)], x=df1['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=2
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<45]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=2
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<45]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=3
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1.Time = pd.to_datetime(df1.Time)
df2.Time = pd.to_datetime(df2.Time)

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<42]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=3
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))
df1.Time = pd.to_datetime(df1.Time)
df2.Time = pd.to_datetime(df2.Time)

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<43]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=4
s=1

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<35]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!

# %%
m=5
n=4
s=2

df1 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s)) #處理
df2 = pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}.csv'.format(m,n,s))

df1 = df1.loc[df1['distance{}'.format(s)]!=20]

df1=df1[df1['distance{}'.format(s)]>20]
df1=df1[df1['distance{}'.format(s)]<46]
df1 = df1.reset_index()
i = 1
while i<(len(df1["distance{}".format(s)])-1):
    a = df1["distance{}".format(s)][i-1]
    b = df1["distance{}".format(s)][i]
    c = df1["distance{}".format(s)][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df1["distance{}".format(s)][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df1.drop(['index'],axis=1)        
df1.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\723\{0}-{1}-d{2}_clean.csv'.format(m,n,s),index=False)

print("SAVE!!!")


# fig = px.line(df1, y='distance{}'.format(s), x='Time')
# fig.add_scatter(y=df2['distance{}'.format(s)], x=df2['Time'])
           
# fig.show()
# print("{0}-{1}-{2}".format(m,n,s))
# Out:
# SAVE!!!
