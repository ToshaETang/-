# %%
import pandas as pd
import datetime
import pytz
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
#---------------------------------------去掉紅色警告-------------
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
m='大竹坑'
n=10
s=1   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<39]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.drop(['index'],axis=1)        
df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<60]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.drop(['index'],axis=1)        
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)      
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='大竹坑'
n=10
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>30]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>30]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='大竹坑'
n=10
s=3   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>39]
df01=df01[df01['distance1']<43]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#
df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>34]
df001=df001[df001['distance2']<41]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='大竹坑'
n=10
s=5   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>30]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='羌黃坑'
n=9
s=1   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='羌黃坑'
n=9
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='羌黃坑'
n=9
s=3   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='羌黃坑'
n=9
s=4   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>25]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='阿里山國小'
n=14
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='阿里山國小'
n=14
s=4   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<80]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='阿里山國小'
n=14
s=5   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<41]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='馬頭山'
n=6
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#        

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>25]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='馬頭山'
n=6
s=3   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<28]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='馬頭山'
n=6
s=5   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

# df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>42]
df001=df001[df001['distance2']<48]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=15
s=1   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>40]
df01=df01[df01['distance1']<49]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>40]
df001=df001[df001['distance2']<47]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=15
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>70]
df01=df01[df01['distance1']<90]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>36]
df001=df001[df001['distance2']<47]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

# df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
# print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.index)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!

# %%
m='健檢'
n=15
s=3   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>30]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>32]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=16
s=1   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>22]
df01=df01[df01['distance1']<32]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

# df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<30]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")
print(df001)

fig2 = px.line(df001, y='distance2', x=df001.datetime)
fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
fig2.show()
print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!
#       index            datetime  distance2
# 0         4 2021-06-30 09:57:52     24.450
# 1         7 2021-07-01 17:46:50     24.060
# 2        13 2021-06-30 14:26:25     23.670
# 3        14 2021-06-30 14:56:20     24.750
# 4        15 2021-06-30 15:26:12     25.110
# ...     ...                 ...        ...
# 1587   1724 2021-08-15 21:20:12     22.045
# 1588   1725 2021-08-15 22:19:57     21.860
# 1589   1727 2021-08-15 21:50:04     22.025
# 1590   1728 2021-08-15 22:49:51     22.190
# 1591   1729 2021-08-15 23:34:21     22.230
#
# [1592 rows x 3 columns]
# ...

# %%
m='健檢'
n=16
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>30]
df01=df01[df01['distance1']<40]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.index)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.index)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=16
s=3   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>30]
df01=df01[df01['distance1']<40]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>30]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=17
s=1   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<60]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>40]
df001=df001[df001['distance2']<60]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=17
s=2   #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<35]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>30]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=17
s=3  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>40]
df01=df01[df01['distance1']<60]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>40]
df001=df001[df001['distance2']<55]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=18
s=1  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<44]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=18
s=2  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<44]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>40]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='健檢'
n=18
s=3  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<38]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<35]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='新美國小'
n=13
s=1  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<50]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<35]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='新美國小'
n=13
s=2  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<40]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='新美國小'
n=13
s=3  #d

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<45]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='隘寮'
n=27
s=1

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<55]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#
df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='隘寮'
n=27
s=2

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>25]
df01=df01[df01['distance1']<55]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#
df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<47]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='奮起湖'
n=8
s=1

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>26]
df01=df01[df01['distance1']<32]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#
# df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>22]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#
df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='奮起湖'
n=8
s=2

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>25]
df01=df01[df01['distance1']<55]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>50]
df001=df001[df001['distance2']<64]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='奮起湖'
n=8
s=3

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>33]
df01=df01[df01['distance1']<55]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>21]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='奮起湖'
n=8
s=4

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<90]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='奮起湖'
n=8
s=5

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>22]
df01=df01[df01['distance1']<55]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>25]
df001=df001[df001['distance2']<50]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='龍美'
n=7
s=1

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<53]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='龍美'
n=7
s=2

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>50]
df01=df01[df01['distance1']<70]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>45]
df001=df001[df001['distance2']<65]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='龍美'
n=7
s=3

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>28]
df001=df001[df001['distance2']<38]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='龍美'
n=7
s=4

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>21]
df001=df001[df001['distance2']<38]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=11
s=1

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<40]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<60]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=11
s=2

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<50]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<60]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=11
s=4

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>20]
df01=df01[df01['distance1']<50]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.index)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>25]
df001=df001[df001['distance2']<55]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=11
s=5

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>60]
df01=df01[df01['distance1']<100]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>60]
df001=df001[df001['distance2']<100]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=12
s=1

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>25]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df01, y='distance1', x=df01.datetime)
# fig.add_scatter(y=df02['distance1'], x=df02.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<100]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df001, y='distance2', x=df001.datetime)
# fig2.add_scatter(y=df002['distance2'], x=df002.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=12
s=2

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>34]
df01=df01[df01['distance1']<42]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<42]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=12
s=3

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>34]
df01=df01[df01['distance1']<45]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df01['datetime']=pd.to_datetime(df01['datetime'])        
df01.set_index('datetime', drop=True, inplace=True)        
df01=df01.resample(rule='1D').mean()
#--#--#

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.index)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<40]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1
        
#--#--#
df001['datetime']=pd.to_datetime(df001['datetime'])        
df001.set_index('datetime', drop=True, inplace=True)        
df001=df001.resample(rule='1D').mean()
#--#--#

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s))
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.index)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
m='關山'
n=12
s=5

df1 = pd.read_excel(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\20210816_抓沖蝕資料\{0}_{1}_{2}_20210501_20210816.xlsx'.format(m,n,s))
# df1['datetime']=pd.to_datetime(df1['datetime'])
# df1=df1.set_index('datetime')


df11=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance2','voltage','server_voltage','time_str'],axis=1)
df12=df1.drop(['watershed','area','detect_type','device_id','device_name','lat','lon','node_id','distance1','voltage','server_voltage','time_str'],axis=1)

df11 = df11.loc[df1['distance1']!=20]
df12 = df12.loc[df1['distance2']!=20]

df11.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d1.csv'.format(m,n,s))
df12.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\{0}_{1}_{2}_d2.csv'.format(m,n,s))
print("資料切割完成")
#---------------------------------------------------------------------------------------------------
df01 = df11  #改過
df02 = df11

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df01=df01[df01['distance1']>65]
df01=df01[df01['distance1']<90]
df01 = df01.reset_index()
i = 1
while i<(len(df01["distance1"])-1):
    a = df01["distance1"][i-1]
    b = df01["distance1"][i]
    c = df01["distance1"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df01["distance1"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df01.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d1_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig = px.line(df02, y='distance1', x=df02.datetime)
# fig.add_scatter(y=df01['distance1'], x=df01.datetime)
           
# fig.show()
# print("{0}-{1}-{2}-d1".format(m,n,s))
################################################
df001 = df12  #改過
df002 = df12

# df1 = df1.loc[df1['distance{}'.format(s)]!=20]


df001=df001[df001['distance2']>20]
df001=df001[df001['distance2']<100]
df001 = df001.reset_index()
i = 1
while i<(len(df001["distance2"])-1):
    a = df001["distance2"][i-1]
    b = df001["distance2"][i]
    c = df001["distance2"][i+1]
    if (abs(b-c)+abs(a-b))/2>abs(c-a)*1.5:
        df001["distance2"][i] = (a+c)/2
        i=i+1
    else:
        i=i+1

df001.to_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\{0}-{1}-{2}-d2_clean.csv'.format(m,n,s),index=False)
print("SAVE!!!")

# fig2 = px.line(df002, y='distance2', x=df002.datetime)
# fig2.add_scatter(y=df001['distance2'], x=df001.datetime)
           
# fig2.show()
# print("{0}-{1}-{2}-d2".format(m,n,s))
# Out:
# 資料切割完成
# SAVE!!!
# SAVE!!!

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-6c3378ad66c6> in <module>
#       1 df9=pd.read_csv(r'C:\Users\Tosha.E.T\Desktop\Sinotech\816\濾過\大竹坑-10-1-d1_clean.csv')
# ----> 2 res= STL(df9.distance1,period=103).fit()
#       3 print(res.seasonal)
#       4 res.plot()
#       5 plt.show()
#
# NameError: name 'STL' is not defined
