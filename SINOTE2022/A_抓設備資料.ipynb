# %%
import requests
import json
import pandas as pd

# %%
url = "https://api.thingspeak.com/channels/468138/feeds.json?"

r = requests.get(url)
jr = json.loads(r.text)

print(jr['feeds'])
# Out:
# [{'created_at': '2022-06-29T11:37:30Z', 'entry_id': 63493, 'field1': '4.14', 'field2': '-26.80', 'field3': '4.14', 'field4': '-43.10', 'field5': '11.01', 'field6': '3.48', 'field7': '2.16'}, {'created_at': '2022-06-29T11:47:28Z', 'entry_id': 63494, 'field1': '4.14', 'field2': '-17.40', 'field3': '4.14', 'field4': '-58.70', 'field5': '7.87', 'field6': '3.49', 'field7': '2.16'}, {'created_at': '2022-06-29T11:57:30Z', 'entry_id': 63495, 'field1': '4.14', 'field2': '-17.40', 'field3': '4.14', 'field4': '-41.40', 'field5': '11.01', 'field6': '3.48', 'field7': '2.16'}, {'created_at': '2022-06-29T12:07:29Z', 'entry_id': 63496, 'field1': '4.14', 'field2': '-16.50', 'field3': '4.13', 'field4': '-112.30', 'field5': '8.22', 'field6': '3.48', 'field7': '2.16'}, {'created_at': '2022-06-29T12:17:30Z', 'entry_id': 63497, 'field1': '4.14', 'field2': '-18.70', 'field3': '4.14', 'field4': '-58.10', 'field5': '11.01', 'field6': '3.48', 'field7': '2.16'}, {'created_at': '2022-06-29T12:27:28Z', 'entry_id
# ...
